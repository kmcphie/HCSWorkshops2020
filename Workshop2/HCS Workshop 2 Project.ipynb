# %%
# HCS Workshop 2, Web Scraping
# Project Submission - Katherine McPhie

# %%
# import requests package and set up page

import requests

page = requests.get("https://www.brainyquote.com/topics/inspirational-quotes")
print(page.status_code)
# Out:
# 200

# %%
# import BeautifulSoup and make a "BeautifulSoup object"

from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-ng-app="bqApp" data-ng-controller="ShowFavoritesCtrl" data-ng-init="initSFC()" lang="en">
#  <head>
#   <title>
#    459 Inspirational Quotes to Explore and Share - Quotes at BrainyQuote
#   </title>
#   <meta content="all" name="robots"/>
#   <meta charset="utf-8">
#    <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
#    <link href="//fonts.gstatic.com" rel="dns-prefetch"/>
#    <link href="//www.google-analytics.com" rel="dns-prefetch"/>
#    <link href="//www.googletagservices.com" rel="dns-prefetch"/>
#    <link href="//www.google.com" rel="dns-prefetch"/>
#    <link href="//adservice.google.com" rel="dns-prefetch"/>
#    <link href="//cdn.ampproject.org" rel="dns-prefetch"/>
#    <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
#    <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
#    <link href="//ad.doubleclick.net" rel="dns-prefetch"/>
#    <link href="//cm.g.doubleclick.net" rel="dns-prefetch"/>
#    <link href="//stats.g.doubleclick.net" rel="dns-prefetch"/>
#    <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
#    <link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/>
#    <link href="//cdn.revive-adserver.net" rel="dns-prefetch"/>
#    <link href="//servedby.revive-adserver.net" rel="dns-prefetch"/>
#    <link href="//ib.adnxs.com" rel="dns-prefetch"/>
#    <link href="//brainyquote-d.openx.net" rel="dns-prefetch"/>
#    <link href="//us-u.openx.net" rel="dns-prefetch"/>
#    <link href="//as-sec.casalemedia.com/" rel="dns-prefetch"/>
#    <link href="//hbopenbid.pubmatic.com/" rel="dns-prefetch"/>
#    <link href="//bidder.criteo.com" rel="dns-prefetch"/>
#    <link href="//ap.lijit.com" rel="dns-prefetch"/>
#    <link href="//gslbeacon.lijit.com" rel="dns-prefetch"/>
#    <link href="//fastlane.rubiconproject.com" rel="dns-prefetch"/>
#    <link href="//web.hb.ad.cpe.dotomi.com" rel="dns-prefetch"/>
#    <meta content="width=device-width, initial-scale=1.0, viewport-fit=cover" name="viewport"/>
#    <meta content="Explore 459 Inspirational Quotes by authors including Ralph Waldo Emerson, Helen Keller, and William Shakespeare at BrainyQuote." name="description"/>
#    <meta content="NOODP" name="googlebot"/>
#    <meta content="10.8.0:4078673" property="ver"/>
#    <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#    <meta content="none" name="msapplication-config"/>
#    <meta content="yes" name="apple-mobile-web-app-capable"/>
#    <meta content="1604420814" property="ts"/>
#    <meta content="BrainyQuote" property="og:site_name"/>
#    <meta content="459 Inspirational Quotes to Explore and Share - Quotes at BrainyQuote" property="og:title"/>
#    <meta content="article" property="og:type"/>
#    <meta content="Explore 459 Inspirational Quotes by authors including Ralph Waldo Emerson, Helen Keller, and William Shakespeare at BrainyQuote." property="og:description"/>
#    <meta content="https://www.brainyquote.com/images/fbl.jpg" property="og:image"/>
#    <meta content="image/jpeg" property="og:image:type"/>
#    <meta content="200" property="og:image:width"/>
#    <meta content="200" property="og:image:height"/>
#    <meta content="summary_large_image" name="twitter:card"/>
#    <meta content="@BrainyQuote" name="twitter:site"/>
#    <meta content="916307096" name="twitter:app:id:iphone"/>
#    <meta content="916307096" name="twitter:app:id:ipad"/>
#    <meta content="@BrainyQuote" name="twitter:creator"/>
#    <meta content="Inspirational Quotes" name="twitter:title"/>
#    <meta content='"The best and most beautiful things in the world cannot be seen or even touched - they must be felt with the heart." - Helen Keller' name="twitter:description"/>
#    <meta content="https://www.brainyquote.com/photos_tr/en/h/helenkeller/101301/helenkeller1.jpg" name="twitter:image"/>
#    <meta content="https://www.brainyquote.com/topics/inspirational-quotes" property="og:url"/>
#    <link href="https://www.brainyquote.com/topics/inspirational-quotes" rel="canonical"/>
#    <meta content="app-id=916307096" name="apple-itunes-app"/>
#    <link href="https://www.brainyquote.com/topics/inspirational-quotes_2" rel="next"/>
#    <link href="/favicon.ico?cbv=3" rel="icon" type="image/x-icon"/>
#    <link href="/favicon.ico?cbv=3" rel="shortcut icon" type="image/x-icon"/>
#    <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#    <link href="/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#    <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#    <link href="/manifest.json" rel="manifest"/>
#    <meta content="BrainyQuote" name="apple-mobile-web-app-title"/>
#    <meta content="BrainyQuote" name="application-name"/>
#    <meta content="#2b5797" name="msapplication-TileColor"/>
#    <meta content="/mstile-144x144.png" name="msapplication-TileImage"/>
#    <meta content="/browserconfig.xml" name="msapplication-config"/>
#    <meta content="#ffffff" name="theme-color"/>
#    <link href="/st/css/4078673/ws_core_msnry.css" media="screen, print" rel="stylesheet" type="text/css"/>
#    <!--[if IE 8]>
# <style>
# #bq-sm-nav-bar { display:none; }
# .navbar-nav { margin: 0px !important; }
# .navbar-form, .form-group { border: 0px !important; }
# </style>
# <![endif]-->
#    <!--[if lte IE 9]>
# <script>BQ_OLD_IE = true;</script>
# <![endif]-->
#    <script type="text/javascript">
#     JsLOG = [];
# document.BQ_START = new Date().getTime();
# window.infoRevn = {a9:false,adMargin:900,adbShow:false,allAdPages:6,auctTimeoutAdmin:1000,bidDivs:false,ctTarg:{"bq_ct":"t","bq_pg":"f","bq_tId":"132618"},ddBullfrog:false,ddTLog:false,delayAuctionMargin:1100,delayAuctions:true,delayDisplay:true,drpP:0,firstInfScrollPos:3,forcebdrp:null,gaDisabledBasedOnPageType:false,infScrollSlotsPerAuction:2,infScrollSpacing:8,intlDrp:5,logPn:false,maxBidEnabled:true,maxBidMult:240,pbBidCaching:false,pbSyncDelay:3000,pbSyncsPerBidder:5,pubcid:true,refreshInterval:0,revnOn:true,secondChance:false,secondPct:50,seoExpGrp:"na",smDefault:7,smLoc:6,smMvsD:2,tadpole:false,uflrPct:10,usDrp:10};
# window.infoSvr = {RID:"4078673",country:"US",isAws:true,isDev:false,isLocal:false,isProd:true,region:"US",svrUID:"i-037774fcf1530c4f2",svrVersion:"10.8.0:4078673"};
# window.infoReq = {abgrp:"a",cpageNum:1,curl:"/topics/inspirational-quotes",domainId:"t:132618",gaPageType:"topic",langc:"en",logTiming:false,lpageNum:12,ngmods:[],searchAutoFocus:true,vid:"06b9f4c728a46e3ea074693745c430be"};
# window.infoUI = {abBtn:"OK",abMsg:"BrainyQuote loves you! Please love us back by whitelisting our site.",asyncScripts:["later","masonry"],infEnabled:false,infLdMargin:1200,listModeDefault:false,pageUsesGrid:true,pageUsesGridOnly:false,redirDom:true};
# document.BQ_ADCFG = {"procfg":{"appnexus":{"adj":"0.99"},"conversant":{"adj":"0.97"},"indexExchange":{"adj":"0.98"},"openx":{"adj":"1.0"},"pubmatic":{"adj":"0.96"},"sovrn":{"adj":"0.98"},"rubicon":{"adj":"0.99"},"criteo":{"adj":"0.98"}},"placements":[{"elementId":"div-gpt-ad-1418667263920-4","sizes":[[300,250],[1,1]],"masonryUseAllowed":true,"name":"/1008298/BQ_ros_square_300x250","sn":"sqT","bdrs":{"criteo":{"uf":false,"am":"f","zoneIds":[1320648],"adj":0.98},"appnexus":{"uf":true,"bfp":0,"am":"f","plid":6524299,"adj":0.99},"pubmatic":{"uf":true,"bfp":0,"am":"f","pubmaticName":"Square"},"rubicon":{"uf":true,"bfp":0,"am":"f","zone":457864,"sizekey":15,"pos":"atf","adj":0.99},"conversant":{"uf":true,"bfp":0,"am":"f","cnvSizes":[[300,250]]},"openx":{"uf":true,"bfp":0,"am":"f","oxAdUnitId":538124062},"sovrn":{"uf":true,"bfp":0,"am":"f","tags":[{"tagName":"Header_BQ_ros_square_300x250","tagId":335425,"width":300,"height":250}]},"indexExchange":{"uf":true,"bfp":0,"am":"f","tags":[{"tagName":"IE_Desktop_top_2","tagId":175234,"tagNum":2,"width":300,"height":250}]}},"hbSizes":[[300,250]]},{"elementId":"div-gpt-ad-1418667263920-3","sizes":[[300,250],[1,1]],"masonryUseAllowed":true,"name":"/1008298/BQ_ros_middle_300x250","sn":"sqM","bdrs":{"criteo":{"uf":false,"am":"f","zoneIds":[1320647],"adj":0.98},"appnexus":{"uf":true,"bfp":0,"am":"f","plid":6524304,"adj":0.99},"pubmatic":{"uf":true,"bfp":0,"am":"f","pubmaticName":"Middle"},"rubicon":{"uf":true,"bfp":0,"am":"f","zone":457866,"sizekey":15,"pos":"atf","adj":0.99},"conversant":{"uf":true,"bfp":0,"am":"f","cnvSizes":[[300,250]]},"openx":{"uf":true,"bfp":0,"am":"f","oxAdUnitId":538124063},"sovrn":{"uf":true,"bfp":0,"am":"f","tags":[{"tagName":"Header_BQ_ros_middle_300x250","tagId":335426,"width":300,"height":250}]},"indexExchange":{"uf":true,"bfp":0,"am":"f","tags":[{"tagName":"IE_Desktop_mid_5","tagId":175237,"tagNum":5,"width":300,"height":250}]}},"hbSizes":[[300,250]]},{"elementId":"div-gpt-ad-1418667263920-2","sizes":[[300,250],[1,1]],"masonryUseAllowed":false,"name":"/1008298/BQ_ros_center_300x250","sn":"sqC","bdrs":{"criteo":{"uf":false,"am":"f","zoneIds":[1320646],"adj":0.98},"appnexus":{"uf":true,"bfp":0,"am":"f","plid":6524307,"adj":0.99},"pubmatic":{"uf":true,"bfp":0,"am":"f","pubmaticName":"Center"},"rubicon":{"uf":true,"bfp":0,"am":"f","zone":457868,"sizekey":15,"altsizekey":10,"pos":"atf","adj":0.99},"conversant":{"uf":true,"bfp":0,"am":"f","cnvSizes":[[300,250]]},"openx":{"uf":true,"bfp":0,"am":"f","oxAdUnitId":538124064},"sovrn":{"uf":true,"bfp":0,"am":"f","tags":[{"tagName":"Header_BQ_ros_center_300x250","tagId":335427,"width":300,"height":250}]},"indexExchange":{"uf":true,"bfp":0,"am":"f","tags":[{"tagName":"IE_Desktop_center_6","tagId":175238,"tagNum":6,"width":300,"height":250}]}},"hbSizes":[[300,250]]},{"elementId":"div-gpt-ad-1418667263920-1","sizes":[[300,250],[1,1]],"masonryUseAllowed":true,"name":"/1008298/BQ_ros_bottom_300x250","sn":"sqB","bdrs":{"criteo":{"uf":false,"am":"f","zoneIds":[1320645],"adj":0.98},"appnexus":{"uf":true,"bfp":0,"am":"f","plid":6524310,"adj":0.99},"pubmatic":{"uf":true,"bfp":0,"am":"f","pubmaticName":"Bottom"},"rubicon":{"uf":true,"bfp":0,"am":"f","zone":457870,"sizekey":15,"pos":"atf","adj":0.99},"conversant":{"uf":true,"bfp":0,"am":"f","cnvSizes":[[300,250]]},"openx":{"uf":true,"bfp":0,"am":"f","oxAdUnitId":538124065},"sovrn":{"uf":true,"bfp":0,"am":"f","tags":[{"tagName":"Header_BQ_ros_bottom_300x250","tagId":335428,"width":300,"height":250}]},"indexExchange":{"uf":true,"bfp":0,"am":"f","tags":[{"tagName":"IE_Desktop_center_7","tagId":175239,"tagNum":7,"width":300,"height":250}]}},"hbSizes":[[300,250]]}],"curi":"/topics/inspirational-quotes"};
# document.BQ_EDATA = {"d":[],"v":[],"cName":"settings","cNum":0};
# document.BQ_SVR_PRED = {"/1008298/BQ_ros_bottom_300x250":1.38,"/1008298/BQ_mobile_anchor":0.36,"/1008298/BQ_mobile_320x50":0.64,"/1008298/BQ_ros_square_300x250":1.4,"/1008298/BQ_ros_middle_300x250":1.32,"/1008298/BQ_ros_top_728x90":1.84,"/1008298/BQ_ros_center_300x250":1.58};
# document.BQ_UNIT_LOOKUP = {"/1008298/BQ_ros_bottom_300x250":"div-gpt-ad-1418667263920-1","/1008298/BQ_ros_square_300x250":"div-gpt-ad-1418667263920-4","/1008298/BQ_ros_middle_300x250":"div-gpt-ad-1418667263920-3","/1008298/BQ_ros_center_300x250":"div-gpt-ad-1418667263920-2"};
# document.BQ_SLOTS = [["main","/1008298/BQ_ros_square_300x250","div-gpt-ad-1418667263920-4"],["main","/1008298/BQ_ros_middle_300x250","div-gpt-ad-1418667263920-3"],["mult_auct2","/1008298/BQ_ros_center_300x250","div-gpt-ad-1418667263920-2"],["mult_auct2","/1008298/BQ_ros_bottom_300x250","div-gpt-ad-1418667263920-1"],["mult_auct3","/1008298/BQ_ros_square_300x250","div-gpt-ad-1418667263920-4"],["mb_footer","/1008298/BQ_ros_middle_300x250","div-gpt-ad-1418667263920-3"],["a2","/1008298/BQ_ros_bottom_300x250","div-gpt-ad-1418667263920-1"]];
# document.BQ_FOOTER_SLOTS = [];
#    </script>
#    <script defer="" src="/st/js/4078673/bq_first.js" type="text/javascript">
#    </script>
#    <script defer="" src="/st/js/4078673/displayad.js" type="text/javascript">
#    </script>
#    <script defer="" src="/st/js/4078673/kgj2PQz45pb347.js" type="text/javascript">
#    </script>
#   </meta>
#  </head>
#  <body class="is-dsk qll-new is-grid-md grid-list-hide">
#   <div data-ng-controller="NavBarCtrl" id="bqNavBarCtrl">
#    <nav class="bq-tnav navbar navbar-default bq-cookie-notice" id="bq-tn-id">
#     <div class="bq-bluebar" style="line-height:10px">
#      <div class="pull-right bq-tnav-right grid-layout-hide" id="bq-tnav-hide">
#       <a class="bq-tnav-btn bq-nav-search-icon fadeable-tn" href="/search">
#        <i class="fa fa-search fa-fw">
#        </i>
#       </a>
#       <div class="bq-nav-search-form">
#        <form action="/search_results" class="no-border bq-no-print form-search" style="padding-left:8px; padding-right:4px">
#         <div class="bq-search">
#          <input class="s-btn fa-input fa fa-search" type="submit" value=""/>
#          <input aria-expanded="false" autocapitalize="off" autocomplete="off" autocorrect="off" class="s-fld-t input-medium search-query s-small" id="bq-search-input" maxlength="80" name="q" placeholder="search" role="combobox" spellcheck="false" type="text" value="">
#          </input>
#         </div>
#        </form>
#       </div>
#       <a class="bq-tnav-btn member" data-ng-click="toggleNavBQCollapsed()" data-ng-init="navBQCollapsed = true" data-ng-show="showMemberActions()" href="#">
#        <i class="fa fa-user">
#        </i>
#       </a>
#       <a class="bq-tnav-btn bars" data-ng-click="toggleHamburgerCollapsed()" data-ng-init="navHamburgerCollapsed = true" href="#">
#        <i class="fa fa-bars">
#        </i>
#       </a>
#      </div>
#      <a class="brand fadeable-tn" href="/" style="padding:0px 5px 0px 15px; color:white">
#       <span alt="Logo" class="bqDesktopLogo">
#       </span>
#      </a>
#      <div class="bq-nav-search-form sm-mbl hide-on-landscape">
#       <form action="/search_results" class="no-border bq-no-print form-search" style="padding-left:8px; padding-right:4px">
#        <div class="bq-search">
#         <input class="s-btn fa-input fa fa-search" type="submit" value=""/>
#         <input aria-expanded="false" autocapitalize="off" autocomplete="off" autocorrect="off" class="s-fld-t input-medium search-query s-small" id="bq-search-input-mbl-por" maxlength="80" name="q" placeholder="search" role="combobox" spellcheck="false" type="text" value="">
#         </input>
#        </div>
#       </form>
#      </div>
#      <ul class="nav navbar-nav hidden-xs" style="float:none; max-height:40px; overflow-y:hidden; display:inline-block">
#       <li class="bq-ni hidden-xs bq-nav-large" id="sl-bq-nav-home-t">
#        <a class="txnav" href="/">
#         Home
#        </a>
#       </li>
#       <li class="bq-ni">
#        <a class="txnav" href="/authors">
#         Authors
#        </a>
#       </li>
#       <li class="bq-ni active">
#        <a class="txnav" href="/topics">
#         Topics
#        </a>
#       </li>
#       <li class="bq-ni">
#        <a class="txnav" href="/quote_of_the_day">
#         Quote Of The Day
#        </a>
#       </li>
#       <li class="bq-ni">
#        <a class="txnav" href="/quote_pictures">
#         Pictures
#        </a>
#       </li>
#      </ul>
#      <div class="bq-right-menu acct-items ng-cloak" data-ng-class="myBQnavBarWrapperClass()" data-ng-show="showMemberActions()">
#       <div class="data-ng-cloak" data-ng-class="myBQnavBarClass()" data-ng-click="navBQCollapsed=true" style="border: none;">
#        <div class="bq-ham-ctr">
#         <div class="bq-ni ni-acct" data-ng-show="showLogin()" el="div">
#          <a class="txnav" href="/signup">
#           <i class="fa fa-pencil-square-o">
#           </i>
#           Sign Up
#          </a>
#         </div>
#         <div class="bq-ni ni-acct" data-ng-show="showLogin()" el="div">
#          <a class="txnav" data-ng-click="loginClicked()" href="#">
#           <i class="fa fa-sign-in">
#           </i>
#           Login
#          </a>
#         </div>
#         <div class="bq-ni ni-acct" data-ng-show="!showLogin()" el="div">
#          <a class="txnav" href="{{getMyFavoritesUrl()}}" rel="nofollow">
#           <i class="fa fa-heart">
#           </i>
#           Favorites
#          </a>
#         </div>
#         <div class="bq-ni ni-acct" data-ng-show="!showLogin()" el="div">
#          <a class="txnav" href="{{getMyCollectionsUrl()}}" rel="nofollow">
#           <i class="fa fa-plus-square-o">
#           </i>
#           Collections
#          </a>
#         </div>
#         <div class="bq-ni ni-acct" data-ng-show="!showLogin()" el="div">
#          <a class="txnav" href="/users/my/account" rel="nofollow">
#           <i class="fa fa-cog">
#           </i>
#           My Account
#          </a>
#         </div>
#         <div class="bq-tnav-divider" data-ng-show="!showLogin()">
#         </div>
#         <div class="bq-ni ni-acct" data-ng-show="!showLogin()" el="div">
#          <a class="txnav" data-ng-click="logoutClicked()" href="#">
#           <i class="fa fa-sign-out">
#           </i>
#           Logout
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="bq-right-menu hamburger-items hidden ng-cloak" data-ng-class="myHamburgerWrapperClass()">
#       <div class="data-ng-cloak" data-ng-class="hamburgerNavBarClass()" data-ng-click="navHamburgerCollapsed=true" style="border: none;">
#        <div class="bq-ham-ctr">
#         <table width="100%">
#          <tr>
#           <td valign="top">
#            <div class="tn-small-header">
#             Site
#            </div>
#            <div class="bq-ni">
#             <a href="/authors">
#              Authors
#             </a>
#            </div>
#            <div class="bq-ni">
#             <a href="/topics">
#              Topics
#             </a>
#            </div>
#            <div class="bq-ni">
#             <a href="/quote_of_the_day">
#              Quote Of The Day
#             </a>
#            </div>
#            <div class="bq-ni">
#             <a href="/quote_pictures">
#              Pictures
#             </a>
#            </div>
#            <div class="bq-ni hide-on-mobile-landscape">
#             <a href="/top_100_quotes">
#              Top 100 Quotes
#             </a>
#            </div>
#            <div class="bq-ni hide-on-mobile-landscape">
#             <a href="/profession/">
#              Professions
#             </a>
#            </div>
#            <div class="bq-ni hide-on-mobile-landscape">
#             <a href="/birthdays/">
#              Birthdays
#             </a>
#            </div>
#            <div class="tn-small-header hide-on-landscape">
#             Apps
#            </div>
#            <div class="bq-ni hide-on-landscape">
#             <a href="/apps/">
#              iPhone/iPad app
#             </a>
#            </div>
#           </td>
#           <td valign="top">
#            <div class="tn-small-header">
#             About
#            </div>
#            <div class="bq-ni">
#             <a href="/about/">
#              About Us
#             </a>
#            </div>
#            <div class="bq-ni hide-on-mobile-landscape">
#             <a href="/about/contact_us">
#              Contact Us
#             </a>
#            </div>
#            <div class="bq-ni">
#             <a href="/about/terms">
#              Terms Of Service
#             </a>
#            </div>
#            <div class="bq-ni">
#             <a href="/about/privacy">
#              Privacy Policy
#             </a>
#            </div>
#           </td>
#           <td class="hide-on-portrait" valign="top">
#            <div class="tn-small-header">
#             Apps
#            </div>
#            <div class="bq-ni">
#             <a href="/apps/">
#              iPhone/iPad app
#             </a>
#            </div>
#           </td>
#          </tr>
#         </table>
#        </div>
#        <div class="bq-right-menu-footer">
#         <a class="bq-copyr" href="/about/copyright">
#          Copyright
#         </a>
#         © 2001 - 2020 BrainyQuote
#        </div>
#       </div>
#      </div>
#     </div>
#    </nav>
#    <div class="bq-subnav">
#     <nav class="navbar navbar-default" style="margin-left:0; margin-right:0">
#      <div class="navbar-header">
#       <h1 class="bq-subnav-h1">
#        Inspirational Quotes
#       </h1>
#      </div>
#      <div class="r_dt grid-layout-hide" id="bq-subnav-hide">
#       <ul class="nav navbar-nav navbar-right hidden-1col">
#        <li class="hidden-2col hidden-1col">
#         <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">
#          Popular Authors
#          <span class="caret">
#          </span>
#         </a>
#         <ul class="dropdown-menu">
#          <li>
#           <a class="bq_on_link_cl" data-xtracl="PA,SubMenu,1" href="/authors/sean-connery-quotes">
#            Sean Connery
#           </a>
#          </li>
#          <li>
#           <a class="bq_on_link_cl" data-xtracl="PA,SubMenu,2" href="/authors/mark-twain-quotes">
#            Mark Twain
#           </a>
#          </li>
#          <li>
#           <a class="bq_on_link_cl" data-xtracl="PA,SubMenu,3" href="/authors/ronald-reagan-quotes">
#            Ronald Reagan
#           </a>
#          </li>
#          <li>
#           <a class="bq_on_link_cl" data-xtracl="PA,SubMenu,4" href="/authors/abraham-lincoln-quotes">
#            Abraham Lincoln
#           </a>
#          </li>
#          <li>
#           <a class="bq_on_link_cl" data-xtracl="PA,SubMenu,5" href="/authors/donald-trump-quotes">
#            Donald Trump
#           </a>
#          </li>
#          <li>
#           <a class="bq_on_link_cl" data-xtracl="PA,SubMenu,6" href="/authors/hugh-hefner-quotes">
#            Hugh Hefner
#           </a>
#          </li>
#          <li>
#           <a class="bq_on_link_cl" data-xtracl="PA,SubMenu,7" href="/authors/benjamin-franklin-quotes">
#            Benjamin Franklin
#           </a>
#          </li>
#          <li>
#           <a class="bq_on_link_cl" data-xtracl="PA,SubMenu,8" href="/authors/william-shakespeare-quotes">
#            William Shakespeare
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="hidden-2col hidden-1col">
#         <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">
#          More
#          <span class="caret">
#          </span>
#         </a>
#         <ul class="dropdown-menu">
#          <li>
#           <a href="/lists/topics/top-10-inspirational-quotes">
#            Top 10 Inspirational Quotes
#           </a>
#          </li>
#          <li>
#           <a href="/citation/topics/inspirational-quotes">
#            Cite this page
#           </a>
#          </li>
#          <li class="divider" role="separator">
#          </li>
#          <li class="dropdown-header">
#           Layout
#          </li>
#          <li>
#           <a href="/topics/inspirational-quotes" onclick="document.cookieUtils.setGridMode();return true;">
#            <i class="bq_grid fa fa-th">
#            </i>
#            Grid
#           </a>
#          </li>
#          <li>
#           <a href="/topics/inspirational-quotes" onclick="document.cookieUtils.setListMode();return true;">
#            <i class="bq_list fa fa-list">
#            </i>
#            List
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a class="fa-lg sh-fb sh-grey" href="/share/fb/u?url=%2Ftopics%2Finspirational-quotes" rel="nofollow" target="_blank">
#          <i class="fa fa-facebook">
#          </i>
#         </a>
#        </li>
#        <li>
#         <a class="fa-lg sh-tw sh-grey" href="/share/tw/u?url=%2Ftopics%2Finspirational-quotes&amp;ti=Inspirational+Quotes" rel="nofollow" target="_blank">
#          <i class="fa fa-twitter">
#          </i>
#         </a>
#        </li>
#        <li>
#         <a class="fa-lg sh-li sh-grey" href="/share/li/u?url=%2Ftopics%2Finspirational-quotes&amp;ti=Inspirational+Quotes+-+BrainyQuote" rel="nofollow" target="_blank">
#          <i class="fa fa-linkedin">
#          </i>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#    </div>
#   </div>
#   <div class="bq-nav-spacer">
#   </div>
#   <noscript>
#    <div class="enableJs">
#     <b>
#      Please enable Javascript
#     </b>
#     <br/>
#     This site requires Javascript to function properly, please enable it.
#    </div>
#   </noscript>
#   <div class="bq-top-spc r_dt">
#   </div>
#   <div class="bq_center ql_page">
#    <div class="reflow_body bq_center">
#     <div class="reflow_container">
#      <div class="new-msnry-grid bqcpx grid-layout-hide" data-sai-includehighlight="true" id="quotesList">
#       <div class="m-brick grid-item boxy bqQt r-width" id="qpos_1_1">
#        <div class="clearfix">
#         <div class="qti-listm">
#          <a class="oncl_q" href="/quotes/helen_keller_101301?src=t_inspirational" title="view quote">
#           <img alt="The best and most beautiful things in the world cannot be seen or even touched - they must be felt with the heart. - Helen Keller" class="bqphtgrid" id="qimage_101301" src="/photos_tr/en/h/helenkeller/101301/helenkeller1.jpg"/>
#          </a>
#         </div>
#         <a class="b-qt qt_101301 oncl_q" href="/quotes/helen_keller_101301?src=t_inspirational" title="view quote">
#          The best and most beautiful things in the world cannot be seen or even touched - they must be felt with the heart.
#         </a>
#         <div style="text-align:left">
#          <a class="bq-aut qa_101301 oncl_a" href="/authors/helen-keller-quotes" title="view author">
#           Helen Keller
#          </a>
#         </div>
#        </div>
#        <div class="qbn-box">
#         <a class="fa-lg sh-fb sh-grey no-margin" href="/share/fb/101301" rel="nofollow" target="_blank">
#          <i class="fa fa-facebook" title="Share on Facebook">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/tw/101301?ti=Inspirational+Quotes" rel="nofollow" target="_blank">
#          <i class="fa fa-twitter" title="Share on Twitter">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/li/101301?ti=Inspirational+Quotes+-+BrainyQuote" rel="nofollow" target="_blank">
#          <i class="fa fa-linkedin" title="Share on LinkedIn">
#          </i>
#         </a>
#         <span class="bqAddQuote bqAddQuoteLg" ng-show="showMemberButtons()">
#          <span class="fa favHeart pointerCursor sh-grey" data-ng-class="favCssClass(101301)">
#          </span>
#          <span class="fa favAddToCol pointerCursor sh-grey" data-ng-class="collectionCssClass(101301)">
#          </span>
#         </span>
#        </div>
#        <div class="qll-dsk-kw-box">
#         <div class="kw-box">
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="0" href="/topics/most-beautiful-quotes">
#           Most Beautiful
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="1" href="/topics/beautiful-quotes">
#           Beautiful
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="2" href="/topics/best-quotes">
#           Best
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="3" href="/topics/heart-quotes">
#           Heart
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="m-brick grid-item boxy bqQt r-width" id="qpos_1_2">
#        <div class="clearfix">
#         <div class="qti-listm">
#          <a class="oncl_q" href="/quotes/francis_of_assisi_121023?src=t_inspirational" title="view quote">
#           <img alt="Start by doing what's necessary; then do what's possible; and suddenly you are doing the impossible. - Francis of Assisi" class="bqphtgrid" id="qimage_121023" src="/photos_tr/en/f/francisofassisi/121023/francisofassisi1.jpg"/>
#          </a>
#         </div>
#         <a class="b-qt qt_121023 oncl_q" href="/quotes/francis_of_assisi_121023?src=t_inspirational" title="view quote">
#          Start by doing what's necessary; then do what's possible; and suddenly you are doing the impossible.
#         </a>
#         <div style="text-align:left">
#          <a class="bq-aut qa_121023 oncl_a" href="/authors/francis-of-assisi-quotes" title="view author">
#           Francis of Assisi
#          </a>
#         </div>
#        </div>
#        <div class="qbn-box">
#         <a class="fa-lg sh-fb sh-grey no-margin" href="/share/fb/121023" rel="nofollow" target="_blank">
#          <i class="fa fa-facebook" title="Share on Facebook">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/tw/121023?ti=Inspirational+Quotes" rel="nofollow" target="_blank">
#          <i class="fa fa-twitter" title="Share on Twitter">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/li/121023?ti=Inspirational+Quotes+-+BrainyQuote" rel="nofollow" target="_blank">
#          <i class="fa fa-linkedin" title="Share on LinkedIn">
#          </i>
#         </a>
#         <span class="bqAddQuote bqAddQuoteLg" ng-show="showMemberButtons()">
#          <span class="fa favHeart pointerCursor sh-grey" data-ng-class="favCssClass(121023)">
#          </span>
#          <span class="fa favAddToCol pointerCursor sh-grey" data-ng-class="collectionCssClass(121023)">
#          </span>
#         </span>
#        </div>
#        <div class="qll-dsk-kw-box">
#         <div class="kw-box">
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="0" href="/topics/you-quotes">
#           You
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="1" href="/topics/impossible-quotes">
#           Impossible
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="2" href="/topics/start-quotes">
#           Start
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="3" href="/topics/doing-quotes">
#           Doing
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="m-brick grid-item boxy bqQt r-width" id="qpos_1_3">
#        <div class="clearfix">
#         <div class="qti-listm">
#          <a class="oncl_q" href="/quotes/ralph_waldo_emerson_386697?src=t_inspirational" title="view quote">
#           <img alt="What lies behind you and what lies in front of you, pales in comparison to what lies inside of you. - Ralph Waldo Emerson" class="bqphtgrid delayedPhotoLoad" data-img-url="/photos_tr/en/r/ralphwaldoemerson/386697/ralphwaldoemerson1.jpg" id="qimage_386697" src="/images/600x315.png"/>
#          </a>
#         </div>
#         <a class="b-qt qt_386697 oncl_q" href="/quotes/ralph_waldo_emerson_386697?src=t_inspirational" title="view quote">
#          What lies behind you and what lies in front of you, pales in comparison to what lies inside of you.
#         </a>
#         <div style="text-align:left">
#          <a class="bq-aut qa_386697 oncl_a" href="/authors/ralph-waldo-emerson-quotes" title="view author">
#           Ralph Waldo Emerson
#          </a>
#         </div>
#        </div>
#        <div class="qbn-box">
#         <a class="fa-lg sh-fb sh-grey no-margin" href="/share/fb/386697" rel="nofollow" target="_blank">
#          <i class="fa fa-facebook" title="Share on Facebook">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/tw/386697?ti=Inspirational+Quotes" rel="nofollow" target="_blank">
#          <i class="fa fa-twitter" title="Share on Twitter">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/li/386697?ti=Inspirational+Quotes+-+BrainyQuote" rel="nofollow" target="_blank">
#          <i class="fa fa-linkedin" title="Share on LinkedIn">
#          </i>
#         </a>
#         <span class="bqAddQuote bqAddQuoteLg" ng-show="showMemberButtons()">
#          <span class="fa favHeart pointerCursor sh-grey" data-ng-class="favCssClass(386697)">
#          </span>
#          <span class="fa favAddToCol pointerCursor sh-grey" data-ng-class="collectionCssClass(386697)">
#          </span>
#         </span>
#        </div>
#        <div class="qll-dsk-kw-box">
#         <div class="kw-box">
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="0" href="/topics/you-quotes">
#           You
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="1" href="/topics/behind-quotes">
#           Behind
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="2" href="/topics/inside-quotes">
#           Inside
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="3" href="/topics/comparison-quotes">
#           Comparison
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="m-ad-brick grid-item m-ad-minh boxy-ad r-width">
#        <div class="mbl_qtbox" id="div-gpt-ad-1418667263920-4_edge">
#         <div class="bq_ad_320x250_multi bqAdCollapse" id="div-gpt-ad-1418667263920-4">
#         </div>
#        </div>
#       </div>
#       <div class="m-brick grid-item boxy bqQt r-width" id="qpos_1_4">
#        <div class="clearfix">
#         <div class="qti-listm">
#          <a class="oncl_q" href="/quotes/jimmy_dean_131287?src=t_inspirational" title="view quote">
#           <img alt="I can't change the direction of the wind, but I can adjust my sails to always reach my destination. - Jimmy Dean" class="bqphtgrid delayedPhotoLoad" data-img-url="/photos_tr/en/j/jimmydean/131287/jimmydean1.jpg" id="qimage_131287" src="/images/600x315.png"/>
#          </a>
#         </div>
#         <a class="b-qt qt_131287 oncl_q" href="/quotes/jimmy_dean_131287?src=t_inspirational" title="view quote">
#          I can't change the direction of the wind, but I can adjust my sails to always reach my destination.
#         </a>
#         <div style="text-align:left">
#          <a class="bq-aut qa_131287 oncl_a" href="/authors/jimmy-dean-quotes" title="view author">
#           Jimmy Dean
#          </a>
#         </div>
#        </div>
#        <div class="qbn-box">
#         <a class="fa-lg sh-fb sh-grey no-margin" href="/share/fb/131287" rel="nofollow" target="_blank">
#          <i class="fa fa-facebook" title="Share on Facebook">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/tw/131287?ti=Inspirational+Quotes" rel="nofollow" target="_blank">
#          <i class="fa fa-twitter" title="Share on Twitter">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/li/131287?ti=Inspirational+Quotes+-+BrainyQuote" rel="nofollow" target="_blank">
#          <i class="fa fa-linkedin" title="Share on LinkedIn">
#          </i>
#         </a>
#         <span class="bqAddQuote bqAddQuoteLg" ng-show="showMemberButtons()">
#          <span class="fa favHeart pointerCursor sh-grey" data-ng-class="favCssClass(131287)">
#          </span>
#          <span class="fa favAddToCol pointerCursor sh-grey" data-ng-class="collectionCssClass(131287)">
#          </span>
#         </span>
#        </div>
#        <div class="qll-dsk-kw-box">
#         <div class="kw-box">
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="0" href="/topics/change-quotes">
#           Change
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="1" href="/topics/destination-quotes">
#           Destination
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="2" href="/topics/wind-quotes">
#           Wind
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="3" href="/topics/always-quotes">
#           Always
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="m-brick grid-item boxy bqQt r-width" id="qpos_1_5">
#        <div class="clearfix">
#         <div class="qti-listm">
#          <a class="oncl_q" href="/quotes/milton_berle_105306?src=t_inspirational" title="view quote">
#           <img alt="If opportunity doesn't knock, build a door. - Milton Berle" class="bqphtgrid delayedPhotoLoad" data-img-url="/photos_tr/en/m/miltonberle/105306/miltonberle1.jpg" id="qimage_105306" src="/images/600x315.png"/>
#          </a>
#         </div>
#         <a class="b-qt qt_105306 oncl_q" href="/quotes/milton_berle_105306?src=t_inspirational" title="view quote">
#          If opportunity doesn't knock, build a door.
#         </a>
#         <div style="text-align:left">
#          <a class="bq-aut qa_105306 oncl_a" href="/authors/milton-berle-quotes" title="view author">
#           Milton Berle
#          </a>
#         </div>
#        </div>
#        <div class="qbn-box">
#         <a class="fa-lg sh-fb sh-grey no-margin" href="/share/fb/105306" rel="nofollow" target="_blank">
#          <i class="fa fa-facebook" title="Share on Facebook">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/tw/105306?ti=Inspirational+Quotes" rel="nofollow" target="_blank">
#          <i class="fa fa-twitter" title="Share on Twitter">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/li/105306?ti=Inspirational+Quotes+-+BrainyQuote" rel="nofollow" target="_blank">
#          <i class="fa fa-linkedin" title="Share on LinkedIn">
#          </i>
#         </a>
#         <span class="bqAddQuote bqAddQuoteLg" ng-show="showMemberButtons()">
#          <span class="fa favHeart pointerCursor sh-grey" data-ng-class="favCssClass(105306)">
#          </span>
#          <span class="fa favAddToCol pointerCursor sh-grey" data-ng-class="collectionCssClass(105306)">
#          </span>
#         </span>
#        </div>
#        <div class="qll-dsk-kw-box">
#         <div class="kw-box">
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="0" href="/topics/opportunity-quotes">
#           Opportunity
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="1" href="/topics/door-quotes">
#           Door
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="2" href="/topics/build-quotes">
#           Build
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="3" href="/topics/knock-quotes">
#           Knock
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="m-brick grid-item boxy bqQt r-width" id="qpos_1_6">
#        <div class="clearfix">
#         <div class="qti-listm">
#          <a class="oncl_q" href="/quotes/aristotle_119068?src=t_inspirational" title="view quote">
#           <img alt="It is during our darkest moments that we must focus to see the light. - Aristotle" class="bqphtgrid delayedPhotoLoad" data-img-url="/photos_tr/en/a/aristotle/119068/aristotle1.jpg" id="qimage_119068" src="/images/600x315.png"/>
#          </a>
#         </div>
#         <a class="b-qt qt_119068 oncl_q" href="/quotes/aristotle_119068?src=t_inspirational" title="view quote">
#          It is during our darkest moments that we must focus to see the light.
#         </a>
#         <div style="text-align:left">
#          <a class="bq-aut qa_119068 oncl_a" href="/authors/aristotle-quotes" title="view author">
#           Aristotle
#          </a>
#         </div>
#        </div>
#        <div class="qbn-box">
#         <a class="fa-lg sh-fb sh-grey no-margin" href="/share/fb/119068" rel="nofollow" target="_blank">
#          <i class="fa fa-facebook" title="Share on Facebook">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/tw/119068?ti=Inspirational+Quotes" rel="nofollow" target="_blank">
#          <i class="fa fa-twitter" title="Share on Twitter">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/li/119068?ti=Inspirational+Quotes+-+BrainyQuote" rel="nofollow" target="_blank">
#          <i class="fa fa-linkedin" title="Share on LinkedIn">
#          </i>
#         </a>
#         <span class="bqAddQuote bqAddQuoteLg" ng-show="showMemberButtons()">
#          <span class="fa favHeart pointerCursor sh-grey" data-ng-class="favCssClass(119068)">
#          </span>
#          <span class="fa favAddToCol pointerCursor sh-grey" data-ng-class="collectionCssClass(119068)">
#          </span>
#         </span>
#        </div>
#        <div class="qll-dsk-kw-box">
#         <div class="kw-box">
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="0" href="/topics/light-quotes">
#           Light
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="1" href="/topics/focus-quotes">
#           Focus
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="2" href="/topics/see-quotes">
#           See
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="3" href="/topics/must-quotes">
#           Must
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="m-brick grid-item boxy bqQt r-width" id="qpos_1_7">
#        <div class="clearfix">
#         <div class="qti-listm">
#          <a class="oncl_q" href="/quotes/william_shakespeare_164317?src=t_inspirational" title="view quote">
#           <img alt="We know what we are, but know not what we may be. - William Shakespeare" class="bqphtgrid delayedPhotoLoad" data-img-url="/photos_tr/en/w/williamshakespeare/164317/williamshakespeare1.jpg" id="qimage_164317" src="/images/600x315.png"/>
#          </a>
#         </div>
#         <a class="b-qt qt_164317 oncl_q" href="/quotes/william_shakespeare_164317?src=t_inspirational" title="view quote">
#          We know what we are, but know not what we may be.
#         </a>
#         <div style="text-align:left">
#          <a class="bq-aut qa_164317 oncl_a" href="/authors/william-shakespeare-quotes" title="view author">
#           William Shakespeare
#          </a>
#         </div>
#        </div>
#        <div class="qbn-box">
#         <a class="fa-lg sh-fb sh-grey no-margin" href="/share/fb/164317" rel="nofollow" target="_blank">
#          <i class="fa fa-facebook" title="Share on Facebook">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/tw/164317?ti=Inspirational+Quotes" rel="nofollow" target="_blank">
#          <i class="fa fa-twitter" title="Share on Twitter">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/li/164317?ti=Inspirational+Quotes+-+BrainyQuote" rel="nofollow" target="_blank">
#          <i class="fa fa-linkedin" title="Share on LinkedIn">
#          </i>
#         </a>
#         <span class="bqAddQuote bqAddQuoteLg" ng-show="showMemberButtons()">
#          <span class="fa favHeart pointerCursor sh-grey" data-ng-class="favCssClass(164317)">
#          </span>
#          <span class="fa favAddToCol pointerCursor sh-grey" data-ng-class="collectionCssClass(164317)">
#          </span>
#         </span>
#        </div>
#        <div class="qll-dsk-kw-box">
#         <div class="kw-box">
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="0" href="/topics/know-quotes">
#           Know
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="1" href="/topics/may-quotes">
#           May
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="m-brick grid-item boxy bqQt r-width" id="qpos_1_8">
#        <div class="clearfix">
#         <div class="qti-listm">
#          <a class="oncl_q" href="/quotes/robert_louis_stevenson_101230?src=t_inspirational" title="view quote">
#           <img alt="Don't judge each day by the harvest you reap but by the seeds that you plant. - Robert Louis Stevenson" class="bqphtgrid delayedPhotoLoad" data-img-url="/photos_tr/en/r/robertlouisstevenson/101230/robertlouisstevenson1.jpg" id="qimage_101230" src="/images/600x315.png"/>
#          </a>
#         </div>
#         <a class="b-qt qt_101230 oncl_q" href="/quotes/robert_louis_stevenson_101230?src=t_inspirational" title="view quote">
#          Don't judge each day by the harvest you reap but by the seeds that you plant.
#         </a>
#         <div style="text-align:left">
#          <a class="bq-aut qa_101230 oncl_a" href="/authors/robert-louis-stevenson-quotes" title="view author">
#           Robert Louis Stevenson
#          </a>
#         </div>
#        </div>
#        <div class="qbn-box">
#         <a class="fa-lg sh-fb sh-grey no-margin" href="/share/fb/101230" rel="nofollow" target="_blank">
#          <i class="fa fa-facebook" title="Share on Facebook">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/tw/101230?ti=Inspirational+Quotes" rel="nofollow" target="_blank">
#          <i class="fa fa-twitter" title="Share on Twitter">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/li/101230?ti=Inspirational+Quotes+-+BrainyQuote" rel="nofollow" target="_blank">
#          <i class="fa fa-linkedin" title="Share on LinkedIn">
#          </i>
#         </a>
#         <span class="bqAddQuote bqAddQuoteLg" ng-show="showMemberButtons()">
#          <span class="fa favHeart pointerCursor sh-grey" data-ng-class="favCssClass(101230)">
#          </span>
#          <span class="fa favAddToCol pointerCursor sh-grey" data-ng-class="collectionCssClass(101230)">
#          </span>
#         </span>
#        </div>
#        <div class="qll-dsk-kw-box">
#         <div class="kw-box">
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="0" href="/topics/you-quotes">
#           You
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="1" href="/topics/day-quotes">
#           Day
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="2" href="/topics/harvest-quotes">
#           Harvest
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="3" href="/topics/plant-quotes">
#           Plant
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="m-brick grid-item boxy bqQt r-width" id="qpos_1_9">
#        <div class="clearfix">
#         <div class="qti-listm">
#          <a class="oncl_q" href="/quotes/vince_lombardi_385070?src=t_inspirational" title="view quote">
#           <img alt="Perfection is not attainable, but if we chase perfection we can catch excellence. - Vince Lombardi" class="bqphtgrid delayedPhotoLoad" data-img-url="/photos_tr/en/v/vincelombardi/385070/vincelombardi1.jpg" id="qimage_385070" src="/images/600x315.png"/>
#          </a>
#         </div>
#         <a class="b-qt qt_385070 oncl_q" href="/quotes/vince_lombardi_385070?src=t_inspirational" title="view quote">
#          Perfection is not attainable, but if we chase perfection we can catch excellence.
#         </a>
#         <div style="text-align:left">
#          <a class="bq-aut qa_385070 oncl_a" href="/authors/vince-lombardi-quotes" title="view author">
#           Vince Lombardi
#          </a>
#         </div>
#        </div>
#        <div class="qbn-box">
#         <a class="fa-lg sh-fb sh-grey no-margin" href="/share/fb/385070" rel="nofollow" target="_blank">
#          <i class="fa fa-facebook" title="Share on Facebook">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/tw/385070?ti=Inspirational+Quotes" rel="nofollow" target="_blank">
#          <i class="fa fa-twitter" title="Share on Twitter">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/li/385070?ti=Inspirational+Quotes+-+BrainyQuote" rel="nofollow" target="_blank">
#          <i class="fa fa-linkedin" title="Share on LinkedIn">
#          </i>
#         </a>
#         <span class="bqAddQuote bqAddQuoteLg" ng-show="showMemberButtons()">
#          <span class="fa favHeart pointerCursor sh-grey" data-ng-class="favCssClass(385070)">
#          </span>
#          <span class="fa favAddToCol pointerCursor sh-grey" data-ng-class="collectionCssClass(385070)">
#          </span>
#         </span>
#        </div>
#        <div class="qll-dsk-kw-box">
#         <div class="kw-box">
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="0" href="/topics/excellence-quotes">
#           Excellence
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="1" href="/topics/perfection-quotes">
#           Perfection
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="2" href="/topics/catch-quotes">
#           Catch
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="3" href="/topics/chase-quotes">
#           Chase
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="m-brick grid-item boxy bqQt r-width" id="qpos_1_10">
#        <div class="clearfix">
#         <div class="qti-listm">
#          <a class="oncl_q" href="/quotes/walt_whitman_384665?src=t_inspirational" title="view quote">
#           <img alt="Keep your face always toward the sunshine - and shadows will fall behind you. - Walt Whitman" class="bqphtgrid delayedPhotoLoad" data-img-url="/photos_tr/en/w/waltwhitman/384665/waltwhitman1.jpg" id="qimage_384665" src="/images/600x315.png"/>
#          </a>
#         </div>
#         <a class="b-qt qt_384665 oncl_q" href="/quotes/walt_whitman_384665?src=t_inspirational" title="view quote">
#          Keep your face always toward the sunshine - and shadows will fall behind you.
#         </a>
#         <div style="text-align:left">
#          <a class="bq-aut qa_384665 oncl_a" href="/authors/walt-whitman-quotes" title="view author">
#           Walt Whitman
#          </a>
#         </div>
#        </div>
#        <div class="qbn-box">
# ...
#          </span>
#          <span class="fa favAddToCol pointerCursor sh-grey" data-ng-class="collectionCssClass(634520)">
#          </span>
#         </span>
#        </div>
#        <div class="qll-dsk-kw-box">
#         <div class="kw-box">
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="0" href="/topics/life-quotes">
#           Life
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="1" href="/topics/humor-quotes">
#           Humor
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="2" href="/topics/passion-quotes">
#           Passion
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="3" href="/topics/style-quotes">
#           Style
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="m-brick grid-item boxy bqQt r-width" id="qpos_1_39">
#        <div class="clearfix">
#         <div class="qti-listm">
#          <a class="oncl_q" href="/quotes/william_allen_white_109740?src=t_inspirational" title="view quote">
#           <img alt="I am not afraid of tomorrow, for I have seen yesterday and I love today! - William Allen White" class="bqphtgrid delayedPhotoLoad" data-img-url="/photos_tr/en/w/williamallenwhite/109740/williamallenwhite1.jpg" id="qimage_109740" src="/images/600x315.png"/>
#          </a>
#         </div>
#         <a class="b-qt qt_109740 oncl_q" href="/quotes/william_allen_white_109740?src=t_inspirational" title="view quote">
#          I am not afraid of tomorrow, for I have seen yesterday and I love today!
#         </a>
#         <div style="text-align:left">
#          <a class="bq-aut qa_109740 oncl_a" href="/authors/william-allen-white-quotes" title="view author">
#           William Allen White
#          </a>
#         </div>
#        </div>
#        <div class="qbn-box">
#         <a class="fa-lg sh-fb sh-grey no-margin" href="/share/fb/109740" rel="nofollow" target="_blank">
#          <i class="fa fa-facebook" title="Share on Facebook">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/tw/109740?ti=Inspirational+Quotes" rel="nofollow" target="_blank">
#          <i class="fa fa-twitter" title="Share on Twitter">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/li/109740?ti=Inspirational+Quotes+-+BrainyQuote" rel="nofollow" target="_blank">
#          <i class="fa fa-linkedin" title="Share on LinkedIn">
#          </i>
#         </a>
#         <span class="bqAddQuote bqAddQuoteLg" ng-show="showMemberButtons()">
#          <span class="fa favHeart pointerCursor sh-grey" data-ng-class="favCssClass(109740)">
#          </span>
#          <span class="fa favAddToCol pointerCursor sh-grey" data-ng-class="collectionCssClass(109740)">
#          </span>
#         </span>
#        </div>
#        <div class="qll-dsk-kw-box">
#         <div class="kw-box">
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="0" href="/topics/love-quotes">
#           Love
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="1" href="/topics/today-quotes">
#           Today
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="2" href="/topics/tomorrow-quotes">
#           Tomorrow
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="3" href="/topics/i-am-quotes">
#           I Am
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="m-brick grid-item boxy bqQt r-width" id="qpos_1_40">
#        <div class="clearfix">
#         <a class="b-qt qt_358534 oncl_q" href="/quotes/kevyn_aucoin_358534?src=t_inspirational" title="view quote">
#          Today I choose life. Every morning when I wake up I can choose joy, happiness, negativity, pain... To feel the freedom that comes from being able to continue to make mistakes and choices - today I choose to feel life, not to deny my humanity but embrace it.
#         </a>
#         <div style="text-align:left">
#          <a class="bq-aut qa_358534 oncl_a" href="/authors/kevyn-aucoin-quotes" title="view author">
#           Kevyn Aucoin
#          </a>
#         </div>
#        </div>
#        <div class="qbn-box">
#         <a class="fa-lg sh-fb sh-grey no-margin" href="/share/fb/358534" rel="nofollow" target="_blank">
#          <i class="fa fa-facebook" title="Share on Facebook">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/tw/358534?ti=Inspirational+Quotes" rel="nofollow" target="_blank">
#          <i class="fa fa-twitter" title="Share on Twitter">
#          </i>
#         </a>
#         <a class="fa-lg sh-tw sh-grey" href="/share/li/358534?ti=Inspirational+Quotes+-+BrainyQuote" rel="nofollow" target="_blank">
#          <i class="fa fa-linkedin" title="Share on LinkedIn">
#          </i>
#         </a>
#         <span class="bqAddQuote bqAddQuoteLg" ng-show="showMemberButtons()">
#          <span class="fa favHeart pointerCursor sh-grey" data-ng-class="favCssClass(358534)">
#          </span>
#          <span class="fa favAddToCol pointerCursor sh-grey" data-ng-class="collectionCssClass(358534)">
#          </span>
#         </span>
#        </div>
#        <div class="qll-dsk-kw-box">
#         <div class="kw-box">
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="0" href="/topics/life-quotes">
#           Life
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="1" href="/topics/happiness-quotes">
#           Happiness
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="2" href="/topics/today-quotes">
#           Today
#          </a>
#          <a class="qkw-btn btn btn-xs oncl_list_kc" data-idx="3" href="/topics/morning-quotes">
#           Morning
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="infScrollFooter">
#    <div class="bq_s hideInfScroll bq_pageNumbersCont">
#     <nav style="height:29px;">
#      <ul class="pagination bq_pageNumbers pagination-centered pagination-sm">
#       <li class="disabled">
#        <a>
#         Prev
#        </a>
#       </li>
#       <li class="active">
#        <span>
#         1
#        </span>
#       </li>
#       <li>
#        <a href="/topics/inspirational-quotes_2">
#         2
#        </a>
#       </li>
#       <li>
#        <a href="/topics/inspirational-quotes_3">
#         3
#        </a>
#       </li>
#       <li>
#        <a href="/topics/inspirational-quotes_4">
#         4
#        </a>
#       </li>
#       <li class="disabled">
#        <span>
#         ..
#        </span>
#       </li>
#       <li>
#        <a href="/topics/inspirational-quotes_12">
#         12
#        </a>
#       </li>
#       <li>
#        <a href="/topics/inspirational-quotes_2">
#         Next
#        </a>
#       </li>
#      </ul>
#     </nav>
#    </div>
#    <div class="r_mb">
#     <div style="height:20px;">
#     </div>
#     <div class="mbl_qtbox" id="div-gpt-ad-1418667263920-3-mb_footer_edge">
#      <div class="bq_ad_320x250_multi bqAdCollapse" id="div-gpt-ad-1418667263920-3-mb_footer">
#      </div>
#     </div>
#     <div style="height:20px;">
#     </div>
#    </div>
#    <div class="container-fluid" style="max-width:1350px;margin-top:25px;margin-bottom:25px;">
#     <div class="row">
#      <div class="col-sm-7 col-md-8 block-style">
#       <div class="bq_s">
#        <h2>
#         Recommended Topics
#        </h2>
#        <div class="col-lg-3 col-md-6 col-sm-6 col-xs-6 block-sm-holder">
#         <a class="block-sm bq_on_link_cl" data-xtracl="RT,Inspirational,1" href="/topics/motivational-quotes">
#          <span class="link-name">
#           Motivational
#           <br>
#            <span>
#             Quotes
#            </span>
#           </br>
#          </span>
#         </a>
#        </div>
#        <div class="col-lg-3 col-md-6 col-sm-6 col-xs-6 block-sm-holder">
#         <a class="block-sm bq_on_link_cl" data-xtracl="RT,Inspirational,2" href="/topics/life-quotes">
#          <span class="link-name">
#           Life
#           <br>
#            <span>
#             Quotes
#            </span>
#           </br>
#          </span>
#         </a>
#        </div>
#        <div class="col-lg-3 col-md-6 col-sm-6 col-xs-6 block-sm-holder">
#         <a class="block-sm bq_on_link_cl" data-xtracl="RT,Inspirational,3" href="/topics/positive-quotes">
#          <span class="link-name">
#           Positive
#           <br>
#            <span>
#             Quotes
#            </span>
#           </br>
#          </span>
#         </a>
#        </div>
#        <div class="col-lg-3 col-md-6 col-sm-6 col-xs-6 block-sm-holder">
#         <a class="block-sm bq_on_link_cl" data-xtracl="RT,Inspirational,4" href="/topics/work-quotes">
#          <span class="link-name">
#           Work
#           <br/>
#           <span>
#            Quotes
#           </span>
#          </span>
#         </a>
#        </div>
#        <div class="col-lg-3 col-md-6 col-sm-6 col-xs-6 block-sm-holder">
#         <a class="block-sm bq_on_link_cl" data-xtracl="RT,Inspirational,5" href="/topics/attitude-quotes">
#          <span class="link-name">
#           Attitude
#           <br/>
#           <span>
#            Quotes
#           </span>
#          </span>
#         </a>
#        </div>
#        <div class="col-lg-3 col-md-6 col-sm-6 col-xs-6 block-sm-holder">
#         <a class="block-sm bq_on_link_cl" data-xtracl="RT,Inspirational,6" href="/topics/god-quotes">
#          <span class="link-name">
#           God
#           <br/>
#           <span>
#            Quotes
#           </span>
#          </span>
#         </a>
#        </div>
#        <div class="col-lg-3 col-md-6 col-sm-6 col-xs-6 block-sm-holder">
#         <a class="block-sm bq_on_link_cl" data-xtracl="RT,Inspirational,7" href="/topics/smile-quotes">
#          <span class="link-name">
#           Smile
#           <br/>
#           <span>
#            Quotes
#           </span>
#          </span>
#         </a>
#        </div>
#        <div class="col-lg-3 col-md-6 col-sm-6 col-xs-6 block-sm-holder">
#         <a class="block-sm bq_on_link_cl" data-xtracl="RT,Inspirational,8" href="/topics/friendship-quotes">
#          <span class="link-name">
#           Friendship
#           <br/>
#           <span>
#            Quotes
#           </span>
#          </span>
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="r_dt">
#       <div class="col-sm-5 col-md-4 bottom-ad-holder">
#        <div class="mbl_qtbox bq_s" id="div-gpt-ad-1418667263920-1-a2_edge">
#         <div class="bq_ad_320x250_multi bqAdCollapse bq-m-center-300-ad" id="div-gpt-ad-1418667263920-1-a2">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div data-ng-controller="BottomNavCtrl" id="bqBotNav">
#     <div class="bq_bot_nav bq-no-print">
#      <div class="container-fluid" style="max-width: 900px">
#       <div class="row">
#        <div class="col-sm-3 col-md-3 col-xs-6">
#         <div style="float:left; position:absolute; top:-25px;">
#          <img alt="BrainyQuote" src="/st/img/4078673/pinwheel.gif"/>
#         </div>
#         <div style="height:75px">
#         </div>
#         <div class="bq_s">
#          <ul class="footer-follow-icons">
#           <li>
#            <a href="https://www.facebook.com/BrainyQuote" target="_blank">
#             <i class="fa fa-facebook">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a href="https://twitter.com/brainyquote" target="_blank">
#             <i class="fa fa-twitter">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a href="https://pinterest.com/brainyquote" target="_blank">
#             <i class="fa fa-pinterest">
#             </i>
#            </a>
#           </li>
#           <li class="follow-padding-fix">
#            <a href="https://instagram.com/brainyquote" target="_blank">
#             <i class="fa fa-instagram">
#             </i>
#            </a>
#           </li>
#          </ul>
#          <div style="clear:both">
#          </div>
#         </div>
#        </div>
#        <div class="col-sm-3 col-md-3 col-xs-6">
#         <div class="bq_s">
#          BrainyQuote has been providing inspirational quotes since 2001 to our worldwide community.
#         </div>
#         <div class="bq_s">
#          <h3>
#           Quote Of The Day Feeds
#          </h3>
#          <div class="bqLn">
#           <a href="/feeds/todays_quote">
#            Javascript and RSS feeds
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/feeds/wordpress_plugin">
#            WordPress plugin
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/feeds/quote_of_the_day_email">
#            Quote of the Day Email
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col-sm-2 col-md-2 col-xs-6">
#         <div class="bq_s">
#          <h3>
#           Site
#          </h3>
#          <div class="bqLn">
#           <a href="/">
#            Home
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/authors">
#            Authors
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/topics">
#            Topics
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/quote_of_the_day">
#            Quote Of The Day
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/quote_pictures">
#            Pictures
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/top_100_quotes">
#            Top 100 Quotes
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/profession/">
#            Professions
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/birthdays/">
#            Birthdays
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col-sm-2 col-md-2 col-xs-6">
#         <div class="bq_s">
#          <h3>
#           About
#          </h3>
#          <div class="bqLn">
#           <a href="/about/">
#            About Us
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/about/contact_us">
#            Contact Us
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/about/submit_quote">
#            Submit
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/about/privacy">
#            Privacy
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/about/terms">
#            Terms
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col-sm-2 col-md-2 col-xs-6">
#         <div class="bq_s">
#          <h3>
#           Apps
#          </h3>
#          <div class="bqLn">
#           <a href="/apps/">
#            iOS app
#           </a>
#          </div>
#          <br/>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="copyLangFooter langSelLink">
#      <div class="container">
#       <div class="row">
#        <div class="col-sm-5 col-md-5">
#         <div class="ftr_nav" style="vertical-align:center; padding-left: 15px">
#          <a href="/about/copyright" style="vertical-align:top">
#           Copyright
#          </a>
#          © 2001 - 2020 BrainyQuote
#         </div>
#        </div>
#        <div class="col-sm-5 col-md-5 usp-footer-hide" id="usp-c">
#         <div class="ftr_nav" id="usp-footer" style="vertical-align:center; padding-left: 15px;">
#          <a href="/ccpa">
#           Do Not Sell My Info
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <script type="application/ld+json">
#      {
# "@context": "http://schema.org",
# "@type": "WebSite",
# "url": "https://www.brainyquote.com/",
# "name": "BrainyQuote",
# "alternateName": "BrainyQuote - Famous Quotes",
# "potentialAction": {
# "@type": "SearchAction",
# "target": "https://www.brainyquote.com/search_results?q={search_term}",
# "query-input": "required name=search_term"
# }
# }
#     </script>
#     <script type="application/ld+json">
#      {
# "@context": "http://schema.org",
# "@type": "BreadcrumbList",
# "itemListElement": [
# {
# "item": {
# "name": "Quote Topics",
# "@id": "https://www.brainyquote.com/topics"
# },
# "@type": "ListItem",
# "position": 1
# },
# {
# "item": {
# "name": "Inspirational Quotes",
# "@id": "https://www.brainyquote.com/topics/inspirational-quotes"
# },
# "@type": "ListItem",
# "position": 2
# }
# ]
# }
#     </script>
#    </div>
#   </div>
#  </body>
# </html>

# %%
# scrape some inspirational quotes

quote_grid = soup.find(id = 'quotesList')
quotes = quote_grid.find_all(class_ = 'clearfix')

for quote in quotes:
    print(quote.get_text())
    print("---------")
# Out:
# The best and most beautiful things in the world cannot be seen or even touched - they must be felt with the heart.
#
# Helen Keller
#
#
# ---------
#
#
#
#
#
#
# Start by doing what's necessary; then do what's possible; and suddenly you are doing the impossible.
#
# Francis of Assisi
#
#
# ---------
#
#
#
#
#
#
# What lies behind you and what lies in front of you, pales in comparison to what lies inside of you.
#
# Ralph Waldo Emerson
#
#
# ---------
#
#
#
#
#
#
# I can't change the direction of the wind, but I can adjust my sails to always reach my destination.
#
# Jimmy Dean
#
#
# ---------
#
#
#
#
#
#
# If opportunity doesn't knock, build a door.
#
# Milton Berle
#
#
# ---------
#
#
#
#
#
#
# It is during our darkest moments that we must focus to see the light.
#
# Aristotle
#
#
# ---------
#
#
#
#
#
#
# We know what we are, but know not what we may be.
#
# William Shakespeare
#
#
# ---------
#
#
#
#
#
#
# Don't judge each day by the harvest you reap but by the seeds that you plant.
#
# Robert Louis Stevenson
#
#
# ---------
#
#
#
#
#
#
# Perfection is not attainable, but if we chase perfection we can catch excellence.
#
# Vince Lombardi
#
#
# ---------
#
#
#
#
#
#
# Keep your face always toward the sunshine - and shadows will fall behind you.
#
# Walt Whitman
#
#
# ---------
#
#
#
#
#
#
# A champion is someone who gets up when he can't.
#
# Jack Dempsey
#
#
# ---------
#
#
#
#
#
#
# I hated every minute of training, but I said, 'Don't quit. Suffer now and live the rest of your life as a champion.'
#
# Muhammad Ali
#
#
# ---------
#
#
#
#
#
#
# If I have seen further than others, it is by standing upon the shoulders of giants.
#
# Isaac Newton
#
#
# ---------
#
#
#
#
#
#
# The best preparation for tomorrow is doing your best today.
#
# H. Jackson Brown, Jr.
#
#
# ---------
#
#
#
#
#
#
# No act of kindness, no matter how small, is ever wasted.
#
# Aesop
#
#
# ---------
#
#
#
#
#
#
# Out of difficulties grow miracles.
#
# Jean de la Bruyere
#
#
# ---------
#
#
#
#
#
#
# We must let go of the life we have planned, so as to accept the one that is waiting for us.
#
# Joseph Campbell
#
#
# ---------
#
#
#
#
#
#
# Ah, but a man's reach should exceed his grasp, Or what's a heaven for?
#
# Robert Browning
#
#
# ---------
#
#
#
#
#
#
# Clouds come floating into my life, no longer to carry rain or usher storm, but to add color to my sunset sky.
#
# Rabindranath Tagore
#
#
# ---------
#
#
#
#
#
#
# Every story I create, creates me. I write to create myself.
#
# Octavia E. Butler
#
#
# ---------
#
#
#
#
#
#
# Even if I knew that tomorrow the world would go to pieces, I would still plant my apple tree.
#
# Martin Luther
#
#
# ---------
#
#
#
#
#
#
# If you believe in yourself and have dedication and pride - and never quit, you'll be a winner. The price of victory is high but so are the rewards.
#
# Bear Bryant
#
#
# ---------
#
#
#
#
#
#
# It is never too late to be what you might have been.
#
# George Eliot
#
#
# ---------
#
#
#
#
#
#
# There are two ways of spreading light: to be the candle or the mirror that reflects it.
#
# Edith Wharton
#
#
# ---------
#
#
#
#
#
#
# Change your thoughts and you change your world.
#
# Norman Vincent Peale
#
#
# ---------
#
#
#
#
#
#
# Your present circumstances don't determine where you can go; they merely determine where you start.
#
# Nido Qubein
#
#
# ---------
#
#
#
#
#
#
# If the world seems cold to you, kindle fires to warm it.
#
# Lucy Larcom
#
#
# ---------
#
#
#
#
#
#
# No matter what people tell you, words and ideas can change the world.
#
# Robin Williams
#
#
# ---------
#
#
#
#
#
#
# Give light and people will find the way.
#
# Ella Baker
#
#
# ---------
#
#
#
#
#
#
# Happiness is a butterfly, which when pursued, is always just beyond your grasp, but which, if you will sit down quietly, may alight upon you.
#
# Nathaniel Hawthorne
#
#
# ---------
#
#
#
#
#
#
# Just don't give up trying to do what you really want to do. Where there is love and inspiration, I don't think you can go wrong.
#
# Ella Fitzgerald
#
#
# ---------
#
# When you get into a tight place and everything goes against you, till it seems as though you could not hang on a minute longer, never give up then, for that is just the place and time that the tide will turn.
#
# Harriet Beecher Stowe
#
#
# ---------
#
# If a man does not keep pace with his companions, perhaps it is because he hears a different drummer. Let him step to the music which he hears, however measured or far away.
#
# Henry David Thoreau
#
#
# ---------
#
#
#
#
#
#
# The only journey is the one within.
#
# Rainer Maria Rilke
#
#
# ---------
#
#
#
#
#
#
# Let us remember: One book, one pen, one child, and one teacher can change the world.
#
# Malala Yousafzai
#
#
# ---------
#
#
#
#
#
#
# Happiness resides not in possessions, and not in gold, happiness dwells in the soul.
#
# Democritus
#
#
# ---------
#
#
#
#
#
#
# I believe every human has a finite number of heartbeats. I don't intend to waste any of mine.
#
# Neil Armstrong
#
#
# ---------
#
# My mission in life is not merely to survive, but to thrive; and to do so with some passion, some compassion, some humor, and some style.
#
# Maya Angelou
#
#
# ---------
#
#
#
#
#
#
# I am not afraid of tomorrow, for I have seen yesterday and I love today!
#
# William Allen White
#
#
# ---------
#
# Today I choose life. Every morning when I wake up I can choose joy, happiness, negativity, pain... To feel the freedom that comes from being able to continue to make mistakes and choices - today I choose to feel life, not to deny my humanity but embrace it.
#
# Kevyn Aucoin
#
#
# ---------
